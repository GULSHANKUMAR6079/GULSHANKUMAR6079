# %% [markdown]
# <a href="https://colab.research.google.com/github/GULSHANKUMAR6079/GULSHANKUMAR6079/blob/main/Copy_of_placement_project_logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as numpy
import pandas as pd

# %%
df=pd.read_csv('/content/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.tail()
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1

# %% [markdown]
# *df.shape :- will give the no. of rows and column present in that particular DATAFRAME *

# %%
df.shape
# Out:
# (100, 4)

# %%
# Steps

# 0. Preprocess + EDA + Feature Selection
# 1. Extract input and output cols
# 2. Scale the values
# 3. Train test split
# 4. Train the model
# 5. Evaluate the model/model selection
# 6. Deploy the model

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB

# %%
df=df.iloc[:,1:]

# %%
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'])

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X=df.iloc[:,0:2]
Y=df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
Y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
Y.shape
# Out:
# (100,)

# %%
X.shape
# Out:
# (100, 2)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 36   5.7  140.0
# 91   7.5  158.0
# 77   7.3   50.0
# 16   5.2  224.0
# 20   6.6  120.0
# ..   ...    ...
# 6    5.7  143.0
# 64   7.0   64.0
# 17   3.3  183.0
# 11   6.9  138.0
# 99   6.2  113.0
#
# [90 rows x 2 columns]

# %%
Y_train
# Out:
# 36    0
# 91    1
# 77    1
# 16    0
# 20    1
#      ..
# 6     0
# 64    1
# 17    0
# 11    1
# 99    1
# Name: placement, Length: 90, dtype: int64

# %%
X_test
# Out:
#     cgpa     iq
# 58   8.0   79.0
# 23   4.7   87.0
# 34   4.8  163.0
# 47   5.2  161.0
# 67   5.0  118.0
# 32   7.0  139.0
# 14   6.1  103.0
# 65   8.1  166.0
# 3    7.4  132.0
# 28   5.2   90.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.24432913,  0.40553364],
#        [ 1.36466756,  0.84942857],
#        [ 1.18589015, -1.813941  ],
#        [-0.69127265,  2.47704331],
#        [ 0.56016922, -0.08768295],
#        [-0.06555172, -0.43293456],
#        [ 0.73894663, -0.82750783],
#        [-1.04882747,  0.43019447],
#        [ 0.2920031 ,  0.10960369],
#        [ 1.63283368, -0.23564793],
#        [ 2.0797772 ,  1.09603686],
#        [-0.95943877,  0.67680276],
#        [-0.87005006, -1.49335022],
#        [ 0.91772404,  1.86052257],
#        [ 0.82833533,  0.38087281],
#        [-2.21088063,  2.69899077],
#        [ 0.11322569,  0.80010691],
#        [-0.51249524,  0.38087281],
#        [-1.22760488,  0.55349861],
#        [-1.76393711, -1.19742027],
#        [ 0.2920031 , -0.50691705],
#        [ 1.36466756,  0.15892534],
#        [-0.95943877, -1.54267188],
#        [-0.87005006, -0.802847  ],
#        [ 0.64955792,  0.75078525],
#        [-1.40638229,  0.6274811 ],
#        [ 1.18589015, -0.18632627],
# ...

# %%
X_test=scaler.fit_transform(X_test)

# %%
X_test
# Out:
# array([[ 1.4373946 , -1.4188587 ],
#        [-1.12660658, -1.16549107],
#        [-1.04890957,  1.24150136],
#        [-0.73812155,  1.17815946],
#        [-0.89351556, -0.18369153],
#        [ 0.66042454,  0.48139849],
#        [-0.0388485 , -0.65875582],
#        [ 1.5150916 ,  1.33651422],
#        [ 0.97121257,  0.25970182],
#        [-0.73812155, -1.07047821]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
clf.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
clf.predict(X_test)
# Out:
# array([1, 0, 0, 0, 0, 1, 0, 1, 1, 0])

# %%
Y_test
# Out:
# 58    1
# 23    0
# 34    0
# 47    0
# 67    0
# 32    1
# 14    0
# 65    1
# 3     1
# 28    0
# Name: placement, dtype: int64

# %%
Y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test,Y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train,Y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >
